# %% [markdown]
# # Anomaly Reproduction (run when data arrives)
#
# OWNER: Phase 1 / data-arrival phase. Reproduce three textbook anomalies end to
# end with correct sign and plausible post-cost magnitude: post-earnings drift,
# 12-minus-1 momentum, and the Monday/weekend effect. This is the gate that must
# pass before the LLM generator is connected. If the harness cannot reproduce known
# results, it is broken and nothing downstream is trustworthy.
